# %%
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import (
    accuracy_score,
    classification_report,
    confusion_matrix
)

# %%
df = pd.read_csv(
    "../data/synthetic_student_dataset.csv"
)

# %%
X = df[
    [
        "study_hours",
        "sleep_hours",
        "attendance_percentage",
        "assignments_completed",
        "screen_time",
        "coding_interest",
        "logical_reasoning",
        "creativity_score",
        "communication_skill",
        "stress_level",
        "performance_score"
    ]
]

# %%
y = df["recommended_career"]

# %%
label_encoder = LabelEncoder()

y_encoded = label_encoder.fit_transform(y)

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X,
    y_encoded,
    test_size=0.2,
    random_state=42
)

# %%
classifier = RandomForestClassifier(
    n_estimators=200,
    random_state=42
)

# %%
classifier.fit(X_train, y_train)
# Out:
# RandomForestClassifier(n_estimators=200, random_state=42)

# %%
y_pred = classifier.predict(X_test)

# %%
accuracy = accuracy_score(
    y_test,
    y_pred
)

print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.7825

# %%
print(
    classification_report(
        y_test,
        y_pred,
        target_names=label_encoder.classes_
    )
)
# Out:
#                      precision    recall  f1-score   support
#
# Backend Development       0.70      0.54      0.61        26
#     Cloud Computing       0.76      0.63      0.69        30
#       Cybersecurity       0.56      0.29      0.38        17
#        Data Science       0.71      0.89      0.79        28
#  DevOps Engineering       0.72      0.88      0.79        69
#    Game Development       0.86      0.89      0.88        64
#  Mobile Development       0.80      0.69      0.74        29
#    Software Testing       0.75      0.84      0.80        58
#        UI/UX Design       0.90      0.86      0.88        66
#     Web Development       0.86      0.46      0.60        13
#
#            accuracy                           0.78       400
#           macro avg       0.76      0.70      0.72       400
#        weighted avg       0.78      0.78      0.77       400

# %%
cm = confusion_matrix(y_test, y_pred)

print(cm)
# Out:
# [[14  0  0  0  9  1  1  1  0  0]
#  [ 2 19  3  1  4  0  0  0  1  0]
#  [ 0  2  5  5  0  1  1  3  0  0]
#  [ 0  0  0 25  0  0  1  2  0  0]
#  [ 0  3  1  0 61  1  0  2  1  0]
#  [ 1  0  0  1  2 57  2  0  1  0]
#  [ 0  0  0  0  2  0 20  6  1  0]
#  [ 1  0  0  3  3  1  0 49  1  0]
#  [ 0  1  0  0  4  2  0  1 57  1]
#  [ 2  0  0  0  0  3  0  1  1  6]]

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.figure(figsize=(12,8))

sns.heatmap(
    cm,
    annot=True,
    fmt="d",
    cmap="Blues",
    xticklabels=label_encoder.classes_,
    yticklabels=label_encoder.classes_
)

plt.xlabel("Predicted")
plt.ylabel("Actual")

plt.title("Career Prediction Confusion Matrix")

plt.xticks(rotation=45)
plt.yticks(rotation=45)

plt.show()

# %% [markdown]
# #### Save Model - Classifier

# %%
import joblib

# %%
joblib.dump(
    classifier,
    "../models/career_classifier.pkl"
)
# Out:
# ['../models/career_classifier.pkl']

# %%
joblib.dump(
    label_encoder,
    "../models/label_encoder.pkl"
)
# Out:
# ['../models/label_encoder.pkl']
